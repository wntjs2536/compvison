# %%
for mystring in "my name is sone":
    print (mystring)
# Out:
# m
# y
#
# n
# a
# m
# e
#
# i
# s
#
# s
# o
# n
# e

# %%
a = 1
b = 2
c = 3
d = 4

# %%
for (x,y) in [(a,1), (b,2), (c,3), (d,4)]:
    print (x)
# Out:
# 1
# 2
# 3
# 4

# %%
for x in range(5):
    print (x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
mylist = ["","two","three","four"]
