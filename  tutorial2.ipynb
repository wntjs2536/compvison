# %%
tu = (23, 'abc', 4.56, (2,3), 'def')
tu[1]
# Out:
# 'abc'

# %%
li = ["abc", 34, 4.34, 23]
li[1]
# Out:
# 34

# %%
st = "hello world"
st[1]
# Out:
# 'e'

# %%
t = (23, 'abc' , 4.56, (2,3), 'def')
t[1]
# Out:
# 'abc'

# %%
t[-3]
# Out:
# 4.56

# %%
t[1:4]
# Out:
# ('abc', 4.56, (2, 3))

# %%
t[1:-1]
# Out:
# ('abc', 4.56, (2, 3))

# %%
t[1:-1:2]
# Out:
# ('abc', (2, 3))

# %%
t[:2]
# Out:
# (23, 'abc')

# %%
t[2:]
# Out:
# (4.56, (2, 3), 'def')

# %%
t[:]
# Out:
# (23, 'abc', 4.56, (2, 3), 'def')

# %%
t = [1,2,4,5]
3 in t
# Out:
# False

# %%
4 in t
# Out:
# True

# %%
4 not in t
# Out:
# False

# %%
a = 'abcde'
'o' in a
# Out:
# False

# %%
a = 'abode'
'o' in a
# Out:
# True

# %%
li = ['abc', 23, 4.34, 23]
li[1] = 45
li
# Out:
# ['abc', 45, 4.34, 23]

# %%
t = (23, 'abc', 4.56, (2,3, 'def')
t[2] = 3.14
# Out:
#   File "<ipython-input-18-a12335693a57>", line 2
#     t[2] = 3.14
#     ^
# SyntaxError: invalid syntax

# %%
t = (23, 'abc', 3.14, (2,3), 'def')

# %%
li = [1,11,31,4,5]
li.append('a')
li
# Out:
# [1, 11, 31, 4, 5, 'a']

# %%
li.insert(2,'i')
li
# Out:
# [1, 11, 'i', 31, 4, 5, 'a']

# %%
li = ['a', 'b','c','b']
li.index('b')
# Out:
# 1

# %%
li.count('b')
# Out:
# 2

# %%
li.remove('b')
li
# Out:
# ['a', 'c', 'b']

# %%
li = [5,2,6,8]

# %%
li.reverse()
li
# Out:
# [8, 6, 2, 5]

# %%
li.sort()
li
# Out:
# [2, 5, 6, 8]
